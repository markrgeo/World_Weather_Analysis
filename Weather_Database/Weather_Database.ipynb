# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs = np.random.uniform(low=-180.00, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = f'https://api.openweathermap.org/data/2.5/weather?lat=57&lon=-2.15&appid={weather_api_key}&units=imperial' 

print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat=57&lon=-2.15&appid=1f53a50b23e0a965e24b9249e4998b3c&units=imperial

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
       
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(), "Lat": city_lat, "Lng": city_lng, "Max Temp": city_max_temp, 
                          "Humidity": city_humidity, "Cloudiness": city_clouds, "Wind Speed": city_wind, 
                          "Country": city_country, "Current Description": city_description})
    
        
    # If an error is experienced, skip the city
    except Exception as e:
        print("City not found. Skipping...")
        pass
        

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | imeni poliny osipenko
# Processing Record 2 of Set 1 | tchibanga
# Processing Record 3 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 1 | adrar
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | sug-aksy
# City not found. Skipping...
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 1 | norman wells
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | marawi
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | pangnirtung
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | tripoli
# Processing Record 32 of Set 1 | bam
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | shoranur
# Processing Record 36 of Set 1 | dakar
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | moosomin
# Processing Record 39 of Set 1 | margate
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | nasice
# Processing Record 42 of Set 1 | amga
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | coro
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | alice springs
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | tura
# Processing Record 49 of Set 1 | darhan
# Processing Record 50 of Set 1 | ust-maya
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | tari
# Processing Record 5 of Set 2 | labuhan
# Processing Record 6 of Set 2 | rokosovo
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | swan hill
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | galveston
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | melchor de mencos
# Processing Record 15 of Set 2 | ichhawar
# Processing Record 16 of Set 2 | meulaboh
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | djibo
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | puerto del rosario
# Processing Record 21 of Set 2 | parrita
# Processing Record 22 of Set 2 | san patricio
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | kangaatsiaq
# Processing Record 26 of Set 2 | milkovo
# Processing Record 27 of Set 2 | henties bay
# Processing Record 28 of Set 2 | abu samrah
# Processing Record 29 of Set 2 | porto novo
# Processing Record 30 of Set 2 | sur
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | marrakesh
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | ridgecrest
# Processing Record 36 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 2 | pimenta bueno
# Processing Record 38 of Set 2 | boa vista
# Processing Record 39 of Set 2 | nylstroom
# City not found. Skipping...
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | samarai
# Processing Record 42 of Set 2 | bima
# Processing Record 43 of Set 2 | atuona
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | deputatskiy
# Processing Record 47 of Set 2 | wexford
# Processing Record 48 of Set 2 | glendive
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | kirakira
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | reyes
# Processing Record 3 of Set 3 | afsin
# Processing Record 4 of Set 3 | chudovo
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | roma
# Processing Record 7 of Set 3 | eyl
# Processing Record 8 of Set 3 | byron bay
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | leningradskiy
# Processing Record 11 of Set 3 | talnakh
# Processing Record 12 of Set 3 | wahiawa
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | zig
# Processing Record 15 of Set 3 | alindao
# Processing Record 16 of Set 3 | yeppoon
# Processing Record 17 of Set 3 | olafsvik
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | yanaul
# Processing Record 20 of Set 3 | hambantota
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | mataura
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | grindavik
# Processing Record 27 of Set 3 | beloha
# Processing Record 28 of Set 3 | sengiley
# Processing Record 29 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 3 | saint augustine
# Processing Record 31 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | san jeronimo
# Processing Record 34 of Set 3 | kaeo
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | ostrovnoy
# Processing Record 37 of Set 3 | sigli
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 40 of Set 3 | gudari
# Processing Record 41 of Set 3 | belmonte
# Processing Record 42 of Set 3 | nador
# Processing Record 43 of Set 3 | juruti
# Processing Record 44 of Set 3 | cajamarca
# Processing Record 45 of Set 3 | winneba
# Processing Record 46 of Set 3 | khalkhal
# Processing Record 47 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 48 of Set 3 | rio gallegos
# Processing Record 49 of Set 3 | sibu
# Processing Record 50 of Set 3 | tiksi
# Processing Record 1 of Set 4 | berlevag
# Processing Record 2 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 4 | vardo
# Processing Record 4 of Set 4 | hobyo
# Processing Record 5 of Set 4 | tommot
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | hofn
# Processing Record 8 of Set 4 | kyabe
# Processing Record 9 of Set 4 | maltahohe
# Processing Record 10 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 4 | cherskiy
# Processing Record 12 of Set 4 | dhidhdhoo
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | vila velha
# Processing Record 15 of Set 4 | batticaloa
# Processing Record 16 of Set 4 | coahuayana
# Processing Record 17 of Set 4 | cayenne
# Processing Record 18 of Set 4 | vanavara
# Processing Record 19 of Set 4 | xam nua
# Processing Record 20 of Set 4 | ahuimanu
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | atar
# Processing Record 23 of Set 4 | muros
# Processing Record 24 of Set 4 | belyy yar
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | lensk
# Processing Record 27 of Set 4 | suruc
# Processing Record 28 of Set 4 | guerrero negro
# Processing Record 29 of Set 4 | chapais
# Processing Record 30 of Set 4 | manokwari
# Processing Record 31 of Set 4 | kiunga
# Processing Record 32 of Set 4 | moose factory
# Processing Record 33 of Set 4 | broken hill
# Processing Record 34 of Set 4 | namibe
# Processing Record 35 of Set 4 | oshakati
# Processing Record 36 of Set 4 | biak
# Processing Record 37 of Set 4 | hermosillo
# Processing Record 38 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 4 | nouadhibou
# Processing Record 40 of Set 4 | comodoro rivadavia
# Processing Record 41 of Set 4 | komsomolskiy
# Processing Record 42 of Set 4 | auki
# Processing Record 43 of Set 4 | mumford
# Processing Record 44 of Set 4 | kieta
# Processing Record 45 of Set 4 | dalianwan
# Processing Record 46 of Set 4 | kurmanayevka
# Processing Record 47 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 4 | karratha
# Processing Record 49 of Set 4 | jamestown
# Processing Record 50 of Set 4 | shubarkuduk
# Processing Record 1 of Set 5 | kyrylivka
# Processing Record 2 of Set 5 | santa cruz
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | muli
# Processing Record 5 of Set 5 | esso
# Processing Record 6 of Set 5 | acobamba
# Processing Record 7 of Set 5 | kroya
# Processing Record 8 of Set 5 | manitouwadge
# Processing Record 9 of Set 5 | titusville
# Processing Record 10 of Set 5 | wajima
# Processing Record 11 of Set 5 | toamasina
# Processing Record 12 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 5 | faya
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | rock falls
# Processing Record 16 of Set 5 | san cristobal
# Processing Record 17 of Set 5 | souillac
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | lydenburg
# Processing Record 20 of Set 5 | nelson bay
# Processing Record 21 of Set 5 | mayo
# Processing Record 22 of Set 5 | boende
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | pacific grove
# Processing Record 25 of Set 5 | khelyulya
# Processing Record 26 of Set 5 | erken-shakhar
# City not found. Skipping...
# Processing Record 27 of Set 5 | longyearbyen
# Processing Record 28 of Set 5 | ippy
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | klaksvik
# Processing Record 31 of Set 5 | shimoda
# Processing Record 32 of Set 5 | tuatapere
# Processing Record 33 of Set 5 | ejido
# Processing Record 34 of Set 5 | birjand
# Processing Record 35 of Set 5 | guanhaes
# Processing Record 36 of Set 5 | port hardy
# Processing Record 37 of Set 5 | marinette
# Processing Record 38 of Set 5 | ballina
# Processing Record 39 of Set 5 | kasempa
# Processing Record 40 of Set 5 | gigmoto
# Processing Record 41 of Set 5 | general roca
# Processing Record 42 of Set 5 | santa rosa
# Processing Record 43 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 5 | mareeba
# Processing Record 46 of Set 5 | taldan
# Processing Record 47 of Set 5 | puerto ayora
# Processing Record 48 of Set 5 | chokurdakh
# Processing Record 49 of Set 5 | dikson
# Processing Record 50 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 6 | sao filipe
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | nampula
# Processing Record 4 of Set 6 | grobina
# Processing Record 5 of Set 6 | paamiut
# Processing Record 6 of Set 6 | wasilla
# Processing Record 7 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 6 | ambon
# Processing Record 9 of Set 6 | alto araguaia
# Processing Record 10 of Set 6 | sungairaya
# Processing Record 11 of Set 6 | sovetskiy
# Processing Record 12 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 6 | mishan
# Processing Record 14 of Set 6 | cochrane
# Processing Record 15 of Set 6 | channel-port aux basques
# Processing Record 16 of Set 6 | bairiki
# Processing Record 17 of Set 6 | chase
# Processing Record 18 of Set 6 | trinidad
# Processing Record 19 of Set 6 | zyryanovsk
# Processing Record 20 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 6 | aden
# Processing Record 23 of Set 6 | saint george
# Processing Record 24 of Set 6 | taoudenni
# Processing Record 25 of Set 6 | otjimbingwe
# Processing Record 26 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 6 | chabahar
# Processing Record 28 of Set 6 | grootfontein
# Processing Record 29 of Set 6 | baiyin
# Processing Record 30 of Set 6 | denau
# City not found. Skipping...
# Processing Record 31 of Set 6 | liuzhou
# Processing Record 32 of Set 6 | manavalakurichi
# Processing Record 33 of Set 6 | kalabo
# Processing Record 34 of Set 6 | san vicente
# Processing Record 35 of Set 6 | husavik
# Processing Record 36 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 6 | manggar
# Processing Record 38 of Set 6 | padang
# Processing Record 39 of Set 6 | vestmanna
# Processing Record 40 of Set 6 | sao jose da coroa grande
# Processing Record 41 of Set 6 | galle
# Processing Record 42 of Set 6 | alugan
# Processing Record 43 of Set 6 | rundu
# Processing Record 44 of Set 6 | nesbyen
# Processing Record 45 of Set 6 | cairns
# Processing Record 46 of Set 6 | ibra
# Processing Record 47 of Set 6 | kyshtovka
# Processing Record 48 of Set 6 | vao
# Processing Record 49 of Set 6 | tasiilaq
# Processing Record 50 of Set 6 | skegness
# Processing Record 1 of Set 7 | port said
# Processing Record 2 of Set 7 | krasnoselkup
# Processing Record 3 of Set 7 | masakin
# Processing Record 4 of Set 7 | saldanha
# Processing Record 5 of Set 7 | salinopolis
# Processing Record 6 of Set 7 | hollins
# Processing Record 7 of Set 7 | tiznit
# Processing Record 8 of Set 7 | semnan
# Processing Record 9 of Set 7 | sevenoaks
# Processing Record 10 of Set 7 | samarkand
# Processing Record 11 of Set 7 | almeirim
# Processing Record 12 of Set 7 | hovd
# Processing Record 13 of Set 7 | columbus
# Processing Record 14 of Set 7 | giresun
# Processing Record 15 of Set 7 | springfield
# Processing Record 16 of Set 7 | zaozerne
# Processing Record 17 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 7 | buraydah
# Processing Record 19 of Set 7 | slatioara
# Processing Record 20 of Set 7 | carauari
# Processing Record 21 of Set 7 | karibib
# Processing Record 22 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 7 | ust-barguzin
# Processing Record 24 of Set 7 | bacolod
# Processing Record 25 of Set 7 | okhotsk
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | pundaguitan
# Processing Record 28 of Set 7 | katsuura
# Processing Record 29 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 30 of Set 7 | rapid city
# Processing Record 31 of Set 7 | tucumcari
# Processing Record 32 of Set 7 | okitipupa
# Processing Record 33 of Set 7 | faanui
# Processing Record 34 of Set 7 | srednekolymsk
# Processing Record 35 of Set 7 | tete
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 7 | sao bento
# Processing Record 39 of Set 7 | winslow
# Processing Record 40 of Set 7 | magadan
# Processing Record 41 of Set 7 | santa helena
# Processing Record 42 of Set 7 | sebring
# Processing Record 43 of Set 7 | lata
# Processing Record 44 of Set 7 | sisimiut
# Processing Record 45 of Set 7 | raudeberg
# Processing Record 46 of Set 7 | la colmena
# Processing Record 47 of Set 7 | guhagar
# Processing Record 48 of Set 7 | ponta delgada
# Processing Record 49 of Set 7 | cabo rojo
# Processing Record 50 of Set 7 | tucuman
# Processing Record 1 of Set 8 | limbang
# Processing Record 2 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 8 | langxiang
# Processing Record 4 of Set 8 | gravdal
# Processing Record 5 of Set 8 | thessalon
# Processing Record 6 of Set 8 | arinos
# Processing Record 7 of Set 8 | carballo
# Processing Record 8 of Set 8 | tigil
# Processing Record 9 of Set 8 | cleethorpes
# Processing Record 10 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 8 | muroto
# Processing Record 12 of Set 8 | olinda
# Processing Record 13 of Set 8 | soyo
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | zamardi
# Processing Record 16 of Set 8 | mahebourg
# Processing Record 17 of Set 8 | sompeta
# Processing Record 18 of Set 8 | kodiak
# Processing Record 19 of Set 8 | mackay
# Processing Record 20 of Set 8 | taquaritinga
# Processing Record 21 of Set 8 | pichayevo
# Processing Record 22 of Set 8 | bira
# Processing Record 23 of Set 8 | kachug
# Processing Record 24 of Set 8 | doha
# Processing Record 25 of Set 8 | lucapa
# Processing Record 26 of Set 8 | la asuncion
# Processing Record 27 of Set 8 | pokhara
# Processing Record 28 of Set 8 | shancheng
# Processing Record 29 of Set 8 | kabin buri
# Processing Record 30 of Set 8 | kodinsk
# Processing Record 31 of Set 8 | valjala
# City not found. Skipping...
# Processing Record 32 of Set 8 | aykhal
# Processing Record 33 of Set 8 | aklavik
# Processing Record 34 of Set 8 | boardman
# Processing Record 35 of Set 8 | stokmarknes
# Processing Record 36 of Set 8 | morondava
# Processing Record 37 of Set 8 | lar gerd
# City not found. Skipping...
# Processing Record 38 of Set 8 | itarema
# Processing Record 39 of Set 8 | sitka
# Processing Record 40 of Set 8 | fez
# Processing Record 41 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 8 | tautira
# Processing Record 43 of Set 8 | flin flon
# Processing Record 44 of Set 8 | nuevo progreso
# Processing Record 45 of Set 8 | tazovskiy
# Processing Record 46 of Set 8 | manado
# Processing Record 47 of Set 8 | bathsheba
# Processing Record 48 of Set 8 | nisia floresta
# Processing Record 49 of Set 8 | senekal
# Processing Record 50 of Set 8 | guanica
# Processing Record 1 of Set 9 | presidencia roque saenz pena
# Processing Record 2 of Set 9 | maceio
# Processing Record 3 of Set 9 | mococa
# Processing Record 4 of Set 9 | nome
# Processing Record 5 of Set 9 | tairua
# Processing Record 6 of Set 9 | rio grande
# Processing Record 7 of Set 9 | kuito
# Processing Record 8 of Set 9 | isla mujeres
# Processing Record 9 of Set 9 | sobolevo
# Processing Record 10 of Set 9 | plettenberg bay
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | novaya lyalya
# Processing Record 13 of Set 9 | fortuna
# Processing Record 14 of Set 9 | raha
# Processing Record 15 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 9 | esperance
# Processing Record 17 of Set 9 | shetpe
# Processing Record 18 of Set 9 | kommunisticheskiy
# Processing Record 19 of Set 9 | le port
# Processing Record 20 of Set 9 | tonekabon
# Processing Record 21 of Set 9 | gat
# Processing Record 22 of Set 9 | henzada
# City not found. Skipping...
# Processing Record 23 of Set 9 | banda aceh
# Processing Record 24 of Set 9 | saint-leu
# Processing Record 25 of Set 9 | isabela
# Processing Record 26 of Set 9 | asfi
# Processing Record 27 of Set 9 | kalemie
# Processing Record 28 of Set 9 | anito
# Processing Record 29 of Set 9 | santana do acarau
# Processing Record 30 of Set 9 | aitape
# Processing Record 31 of Set 9 | boone
# Processing Record 32 of Set 9 | znamenskoye
# Processing Record 33 of Set 9 | laguna
# Processing Record 34 of Set 9 | beringovskiy
# Processing Record 35 of Set 9 | natal
# Processing Record 36 of Set 9 | ylivieska
# Processing Record 37 of Set 9 | yuma
# Processing Record 38 of Set 9 | calabozo
# Processing Record 39 of Set 9 | mount isa
# Processing Record 40 of Set 9 | stupino
# Processing Record 41 of Set 9 | belaya gora
# Processing Record 42 of Set 9 | chifeng
# Processing Record 43 of Set 9 | flinders
# Processing Record 44 of Set 9 | axim
# Processing Record 45 of Set 9 | salalah
# Processing Record 46 of Set 9 | quarai
# Processing Record 47 of Set 9 | gisborne
# Processing Record 48 of Set 9 | nalut
# Processing Record 49 of Set 9 | pindiga
# Processing Record 50 of Set 9 | havre-saint-pierre
# Processing Record 1 of Set 10 | vostok
# Processing Record 2 of Set 10 | mende
# Processing Record 3 of Set 10 | saryozek
# Processing Record 4 of Set 10 | ugoofaaru
# Processing Record 5 of Set 10 | alipur
# Processing Record 6 of Set 10 | bowen
# Processing Record 7 of Set 10 | jhargram
# Processing Record 8 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 10 | ewa beach
# Processing Record 10 of Set 10 | kailua
# Processing Record 11 of Set 10 | oktyabrskiy
# Processing Record 12 of Set 10 | udachnyy
# Processing Record 13 of Set 10 | puerto palomas
# Processing Record 14 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 10 | kudat
# Processing Record 16 of Set 10 | uaua
# Processing Record 17 of Set 10 | pascagoula
# City not found. Skipping...
# Processing Record 18 of Set 10 | azar shahr
# City not found. Skipping...
# Processing Record 19 of Set 10 | dothan
# Processing Record 20 of Set 10 | batagay-alyta
# Processing Record 21 of Set 10 | jiamusi
# Processing Record 22 of Set 10 | port macquarie
# Processing Record 23 of Set 10 | avera
# Processing Record 24 of Set 10 | guilin
# Processing Record 25 of Set 10 | la paz centro
# Processing Record 26 of Set 10 | portland
# Processing Record 27 of Set 10 | sao joao da barra
# Processing Record 28 of Set 10 | romhany
# Processing Record 29 of Set 10 | yermakovskoye
# Processing Record 30 of Set 10 | gao
# Processing Record 31 of Set 10 | nyamuswa
# Processing Record 32 of Set 10 | vicosa do ceara
# Processing Record 33 of Set 10 | port blair
# Processing Record 34 of Set 10 | mitsamiouli
# Processing Record 35 of Set 10 | kamennomostskoye
# Processing Record 36 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 10 | cantagalo
# Processing Record 38 of Set 10 | clyde river
# Processing Record 39 of Set 10 | westport
# Processing Record 40 of Set 10 | korla
# Processing Record 41 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 42 of Set 10 | san jose
# Processing Record 43 of Set 10 | richards bay
# Processing Record 44 of Set 10 | karaj
# Processing Record 45 of Set 10 | puri
# Processing Record 46 of Set 10 | jalu
# Processing Record 47 of Set 10 | sept-iles
# Processing Record 48 of Set 10 | kashi
# Processing Record 49 of Set 10 | borogontsy
# Processing Record 50 of Set 10 | parati
# Processing Record 1 of Set 11 | bethel
# Processing Record 2 of Set 11 | ankara
# Processing Record 3 of Set 11 | saint-denis
# Processing Record 4 of Set 11 | huarmey
# Processing Record 5 of Set 11 | seoul
# Processing Record 6 of Set 11 | najran
# Processing Record 7 of Set 11 | sistranda
# Processing Record 8 of Set 11 | kargala
# Processing Record 9 of Set 11 | mersing
# Processing Record 10 of Set 11 | viking
# Processing Record 11 of Set 11 | jardim
# Processing Record 12 of Set 11 | arivonimamo
# Processing Record 13 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 14 of Set 11 | florianopolis
# Processing Record 15 of Set 11 | ahipara
# Processing Record 16 of Set 11 | sisophon
# Processing Record 17 of Set 11 | nikki
# Processing Record 18 of Set 11 | talcahuano
# Processing Record 19 of Set 11 | anadyr
# Processing Record 20 of Set 11 | guapiacu
# Processing Record 21 of Set 11 | vicuna
# Processing Record 22 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 23 of Set 11 | port hedland
# Processing Record 24 of Set 11 | north bend
# Processing Record 25 of Set 11 | la union
# Processing Record 26 of Set 11 | sao gabriel da cachoeira
# Processing Record 27 of Set 11 | luwingu
# Processing Record 28 of Set 11 | dingle
# Processing Record 29 of Set 11 | aldan
# Processing Record 30 of Set 11 | acapulco
# Processing Record 31 of Set 11 | fare
# Processing Record 32 of Set 11 | mount gambier
# Processing Record 33 of Set 11 | la ronge
# Processing Record 34 of Set 11 | hami
# Processing Record 35 of Set 11 | podgornoye
# Processing Record 36 of Set 11 | la rioja
# Processing Record 37 of Set 11 | ascension
# Processing Record 38 of Set 11 | yilan
# Processing Record 39 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 11 | umm kaddadah
# Processing Record 41 of Set 11 | yarmolyntsi
# Processing Record 42 of Set 11 | hukuntsi
# Processing Record 43 of Set 11 | lakes entrance
# Processing Record 44 of Set 11 | moerai
# Processing Record 45 of Set 11 | dubbo
# Processing Record 46 of Set 11 | mitchell
# Processing Record 47 of Set 11 | omboue
# Processing Record 48 of Set 11 | quang ngai
# Processing Record 49 of Set 11 | agadez
# Processing Record 50 of Set 11 | yarovoye
# Processing Record 1 of Set 12 | takoradi
# Processing Record 2 of Set 12 | te anau
# Processing Record 3 of Set 12 | high rock
# Processing Record 4 of Set 12 | pantai remis
# Processing Record 5 of Set 12 | alekseyevka
# Processing Record 6 of Set 12 | nchelenge
# Processing Record 7 of Set 12 | los llanos de aridane
# Processing Record 8 of Set 12 | lokosovo
# Processing Record 9 of Set 12 | ransang
# Processing Record 10 of Set 12 | benque viejo
# City not found. Skipping...
# Processing Record 11 of Set 12 | barra
# Processing Record 12 of Set 12 | sabang
# Processing Record 13 of Set 12 | klenovyy
# Processing Record 14 of Set 12 | maragogi
# Processing Record 15 of Set 12 | roald
# Processing Record 16 of Set 12 | ardakan
# Processing Record 17 of Set 12 | mocuba
# Processing Record 18 of Set 12 | sorland
# Processing Record 19 of Set 12 | dingtao
# Processing Record 20 of Set 12 | gaya
# Processing Record 21 of Set 12 | lompoc
# Processing Record 22 of Set 12 | grand gaube
# Processing Record 23 of Set 12 | liling
# Processing Record 24 of Set 12 | cap malheureux
# Processing Record 25 of Set 12 | namatanai
# Processing Record 26 of Set 12 | zapolyarnyy
# Processing Record 27 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 12 | verkhnevilyuysk
# Processing Record 29 of Set 12 | mosquera
# Processing Record 30 of Set 12 | corner brook
# Processing Record 31 of Set 12 | bukama
# Processing Record 32 of Set 12 | cabo san lucas
# Processing Record 33 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 12 | longyan
# Processing Record 35 of Set 12 | benguela
# Processing Record 36 of Set 12 | marzuq
# Processing Record 37 of Set 12 | barpali
# Processing Record 38 of Set 12 | fort nelson
# Processing Record 39 of Set 12 | tokur
# Processing Record 40 of Set 12 | nola
# Processing Record 41 of Set 12 | dauphin
# Processing Record 42 of Set 12 | san carlos de bariloche
# Processing Record 43 of Set 12 | constitucion
# Processing Record 44 of Set 12 | hoquiam
# Processing Record 45 of Set 12 | ambilobe
# Processing Record 46 of Set 12 | listvyanka
# Processing Record 47 of Set 12 | lyaskelya
# Processing Record 48 of Set 12 | wewak
# Processing Record 49 of Set 12 | gorom-gorom
# Processing Record 50 of Set 12 | derzhavinsk
# Processing Record 1 of Set 13 | basoko
# Processing Record 2 of Set 13 | peterhead
# Processing Record 3 of Set 13 | puerto leguizamo
# Processing Record 4 of Set 13 | kalmunai
# Processing Record 5 of Set 13 | sinnamary
# Processing Record 6 of Set 13 | cabra
# Processing Record 7 of Set 13 | foshan
# Processing Record 8 of Set 13 | awjilah
# Processing Record 9 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 13 | alta floresta
# Processing Record 11 of Set 13 | kitob
# Processing Record 12 of Set 13 | saint-ambroise
# Processing Record 13 of Set 13 | berea
# Processing Record 14 of Set 13 | hals
# Processing Record 15 of Set 13 | pimentel
# Processing Record 16 of Set 13 | lugovoy
# Processing Record 17 of Set 13 | shingu
# Processing Record 18 of Set 13 | kununurra
# Processing Record 19 of Set 13 | wairoa
# Processing Record 20 of Set 13 | porto walter
# Processing Record 21 of Set 13 | itacoatiara
# Processing Record 22 of Set 13 | swan river
# Processing Record 23 of Set 13 | manaure
# Processing Record 24 of Set 13 | payo
# Processing Record 25 of Set 13 | yar-sale
# Processing Record 26 of Set 13 | kyra
# Processing Record 27 of Set 13 | carutapera
# Processing Record 28 of Set 13 | maunabo
# Processing Record 29 of Set 13 | ailigandi
# Processing Record 30 of Set 13 | ulladulla
# Processing Record 31 of Set 13 | ilhabela
# Processing Record 32 of Set 13 | nemuro
# Processing Record 33 of Set 13 | harrismith
# Processing Record 34 of Set 13 | lumberton
# Processing Record 35 of Set 13 | shelburne
# Processing Record 36 of Set 13 | havelock
# Processing Record 37 of Set 13 | codrington
# Processing Record 38 of Set 13 | salamiyah
# Processing Record 39 of Set 13 | qrendi
# Processing Record 40 of Set 13 | dandong
# Processing Record 41 of Set 13 | guarda
# Processing Record 42 of Set 13 | mizan teferi
# Processing Record 43 of Set 13 | thunder bay
# Processing Record 44 of Set 13 | port maria
# Processing Record 45 of Set 13 | evensk
# Processing Record 46 of Set 13 | kolokani
# Processing Record 47 of Set 13 | mopipi
# Processing Record 48 of Set 13 | uvat
# Processing Record 49 of Set 13 | busdi
# Processing Record 50 of Set 13 | antofagasta
# Processing Record 1 of Set 14 | pangody
# Processing Record 2 of Set 14 | quatre cocos
# Processing Record 3 of Set 14 | vila franca do campo
# Processing Record 4 of Set 14 | kantunilkin
# Processing Record 5 of Set 14 | sao felix do xingu
# Processing Record 6 of Set 14 | barra do corda
# Processing Record 7 of Set 14 | saint-francois
# Processing Record 8 of Set 14 | abay
# Processing Record 9 of Set 14 | camapua
# Processing Record 10 of Set 14 | itoman
# Processing Record 11 of Set 14 | miyako
# Processing Record 12 of Set 14 | mwandiga
# Processing Record 13 of Set 14 | psebay
# Processing Record 14 of Set 14 | magdagachi
# Processing Record 15 of Set 14 | burnie
# Processing Record 16 of Set 14 | tiarei
# Processing Record 17 of Set 14 | kismayo
# Processing Record 18 of Set 14 | touros
# Processing Record 19 of Set 14 | moses lake
# Processing Record 20 of Set 14 | mountain home
# Processing Record 21 of Set 14 | ambo
# Processing Record 22 of Set 14 | filadelfia
# Processing Record 23 of Set 14 | geraldton
# Processing Record 24 of Set 14 | alofi
# Processing Record 25 of Set 14 | niort
# Processing Record 26 of Set 14 | berdigestyakh
# Processing Record 27 of Set 14 | muyezerskiy
# Processing Record 28 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 14 | omsukchan
# Processing Record 30 of Set 14 | santa vitoria do palmar
# Processing Record 31 of Set 14 | turkistan
# Processing Record 32 of Set 14 | mentougou
# Processing Record 33 of Set 14 | san joaquin
# Processing Record 34 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 14 | wattens
# Processing Record 36 of Set 14 | esquipulas
# Processing Record 37 of Set 14 | benicarlo
# Processing Record 38 of Set 14 | aberdeen
# Processing Record 39 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 14 | portalegre
# Processing Record 41 of Set 14 | gimli
# Processing Record 42 of Set 14 | kobojango
# City not found. Skipping...
# Processing Record 43 of Set 14 | inhambane
# Processing Record 44 of Set 14 | pietersburg
# Processing Record 45 of Set 14 | nantucket
# Processing Record 46 of Set 14 | half moon bay
# Processing Record 47 of Set 14 | madang
# Processing Record 48 of Set 14 | damara
# Processing Record 49 of Set 14 | atasu
# Processing Record 50 of Set 14 | eregli
# Processing Record 1 of Set 15 | camaqua
# Processing Record 2 of Set 15 | millau
# Processing Record 3 of Set 15 | erenhot
# Processing Record 4 of Set 15 | lorengau
# Processing Record 5 of Set 15 | talara
# Processing Record 6 of Set 15 | leon
# Processing Record 7 of Set 15 | college
# Processing Record 8 of Set 15 | chimbote
# Processing Record 9 of Set 15 | sciacca
# Processing Record 10 of Set 15 | bhawanipatna
# Processing Record 11 of Set 15 | shieli
# Processing Record 12 of Set 15 | guarapuava
# Processing Record 13 of Set 15 | turka
# Processing Record 14 of Set 15 | lander
# Processing Record 15 of Set 15 | andenes
# Processing Record 16 of Set 15 | harper
# Processing Record 17 of Set 15 | slupsk
# Processing Record 18 of Set 15 | winter park
# Processing Record 19 of Set 15 | purwakarta
# Processing Record 20 of Set 15 | prabumulih
# Processing Record 21 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 15 | iquique
# Processing Record 23 of Set 15 | aracaju
# Processing Record 24 of Set 15 | muborak
# Processing Record 25 of Set 15 | leh
# Processing Record 26 of Set 15 | tyukhtet
# Processing Record 27 of Set 15 | rongcheng
# Processing Record 28 of Set 15 | ketchikan
# Processing Record 29 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 15 | yumen
# Processing Record 31 of Set 15 | broome
# Processing Record 32 of Set 15 | bonavista
# Processing Record 33 of Set 15 | houma
# Processing Record 34 of Set 15 | cristalina
# Processing Record 35 of Set 15 | buchanan
# Processing Record 36 of Set 15 | hutchinson
# Processing Record 37 of Set 15 | ombessa
# Processing Record 38 of Set 15 | kulhudhuffushi
# Processing Record 39 of Set 15 | kaabong
# Processing Record 40 of Set 15 | domoni
# Processing Record 41 of Set 15 | hamilton
# Processing Record 42 of Set 15 | isangel
# Processing Record 43 of Set 15 | tyup
# Processing Record 44 of Set 15 | west bay
# Processing Record 45 of Set 15 | acarau
# Processing Record 46 of Set 15 | changying
# Processing Record 47 of Set 15 | kumagaya
# Processing Record 48 of Set 15 | terney
# Processing Record 49 of Set 15 | katobu
# Processing Record 50 of Set 15 | zeya
# Processing Record 1 of Set 16 | jumla
# Processing Record 2 of Set 16 | fort frances
# Processing Record 3 of Set 16 | shache
# Processing Record 4 of Set 16 | omaruru
# Processing Record 5 of Set 16 | puerto quijarro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Imeni Poliny Osipenko  52.4201  136.4853    -34.29       100          66
# 1              Tchibanga  -2.8500   11.0333     79.68        87          70
# 2                  Adrar  20.5022  -10.0711     76.30        13         100
# 3             Nikolskoye  59.7035   30.7861     33.80        93         100
# 4                  Kapaa  22.0752 -159.3190     73.72        86           0
# 5                  Vaini -21.2000 -175.2000     77.16        94          75
# 6                 Hobart -42.8794  147.3294     57.06        72         100
# 7           Norman Wells  65.2820 -126.8329    -27.36        75          40
# 8                 Avarua -21.2078 -159.7750     73.45       100          23
# 9                Rikitea -23.1203 -134.9692     79.09        75           4
#
#    Wind Speed Country Current Description
# 0        2.30      RU       broken clouds
# 1        3.85      GA       broken clouds
# 2       12.19      MR     overcast clouds
# 3        7.11      RU     overcast clouds
# 4       23.02      US           clear sky
# 5        4.61      TO          light rain
# 6        3.44      AU     overcast clouds
# 7        3.44      CA    scattered clouds
# 8        2.30      CK          few clouds
# 9       13.67      PF          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  
                    "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Imeni Poliny Osipenko      RU  52.4201  136.4853    -34.29       100
# 1              Tchibanga      GA  -2.8500   11.0333     79.68        87
# 2                  Adrar      MR  20.5022  -10.0711     76.30        13
# 3             Nikolskoye      RU  59.7035   30.7861     33.80        93
# 4                  Kapaa      US  22.0752 -159.3190     73.72        86
# 5                  Vaini      TO -21.2000 -175.2000     77.16        94
# 6                 Hobart      AU -42.8794  147.3294     57.06        72
# 7           Norman Wells      CA  65.2820 -126.8329    -27.36        75
# 8                 Avarua      CK -21.2078 -159.7750     73.45       100
# 9                Rikitea      PF -23.1203 -134.9692     79.09        75
#
#    Cloudiness  Wind Speed Current Description
# 0          66        2.30       broken clouds
# 1          70        3.85       broken clouds
# 2         100       12.19     overcast clouds
# 3         100        7.11     overcast clouds
# 4           0       23.02           clear sky
# 5          75        4.61          light rain
# 6         100        3.44     overcast clouds
# 7          40        3.44    scattered clouds
# 8          23        2.30          few clouds
# 9           4       13.67          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv('WeatherPy_Database.csv', index_label="City_ID")
